# %%
import spacy

# %%
#https://www.youtube.com/watch?v=wpyCzodvO3A
#http://ner.pythonhumanities.com/intro.html

# %%
with open("alice_in_wonderland.txt") as datei:
    text= datei.read()
    datei.close()

# %%
nlp = spacy.load("en_core_web_trf")

# %%
doc = nlp(text)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (705 > 512). Running this sequence through the model will result in indexing errors
# c:\users\mw\appdata\local\programs\python\python39\lib\site-packages\torch\autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Alice 526 531 PERSON
# Alice 918 923 PERSON
# Alice 1290 1295 PERSON
# Alice 1633 1638 PERSON
# Alice 1827 1832 PERSON
# First 2105 2110 ORDINAL
# Alice 2668 2673 PERSON
# four thousand miles 3129 3148 QUANTITY
# Alice 3181 3186 PERSON
# Alice 3522 3527 PERSON
# New Zealand 4027 4038 GPE
# Australia 4042 4051 GPE
# Alice 4375 4380 PERSON
# Dinah'll 4409 4417 PERSON
# to-night 4436 4444 TIME
# Dinah 4465 4470 PERSON
# Dinah 4544 4549 PERSON
# Alice 4748 4753 PERSON
# Dinah 5112 5117 PERSON
# Dinah 5159 5164 PERSON
# Alice 5318 5323 PERSON
# Alice 5578 5583 PERSON
# Rabbit 5770 5776 PERSON
# Alice 5976 5981 PERSON
# three 6168 6173 CARDINAL
# Alice 6267 6272 PERSON
# first 6275 6280 ORDINAL
# second 6481 6487 ORDINAL
# about fifteen inches 6588 6608 QUANTITY
# Alice 6700 6705 PERSON
# Alice 7117 7122 PERSON
# Alice 7347 7352 PERSON
# Alice 7721 7726 PERSON
# Alice 7914 7919 PERSON
# first 7973 7978 ORDINAL
# Alice 8602 8607 PERSON
# Alice 9011 9016 PERSON
# ...

# %%
import pandas

# %%
liste = []

# %%
liste
# Out:
# ['Alice',
#  526,
#  531,
#  'Alice',
#  918,
#  923,
#  'Alice',
#  1290,
#  1295,
#  'Alice',
#  1633,
#  1638,
#  'Alice',
#  1827,
#  1832,
#  'Alice',
#  2668,
#  2673,
#  'Alice',
#  3181,
#  3186,
#  'Alice',
#  3522,
#  3527,
#  'Alice',
#  4375,
#  4380,
#  "Dinah'll",
#  4409,
#  4417,
#  'Dinah',
#  4465,
#  4470,
#  'Dinah',
#  4544,
#  4549,
#  'Alice',
#  4748,
#  4753,
#  'Dinah',
#  5112,
#  5117,
#  'Dinah',
#  5159,
#  5164,
#  'Alice',
#  5318,
#  5323,
#  'Alice',
#  5578,
#  5583,
#  'Rabbit',
#  5770,
#  5776,
#  'Alice',
#  5976,
#  5981,
#  'Alice',
#  6267,
#  6272,
#  'Alice',
#  6700,
#  6705,
#  'Alice',
#  7117,
#  7122,
#  'Alice',
#  7347,
#  7352,
#  'Alice',
#  7721,
#  7726,
#  'Alice',
#  7914,
#  7919,
#  'Alice',
#  8602,
#  8607,
#  'Alice',
#  9011,
#  9016,
#  'Alice',
#  9419,
#  9424,
#  'Alice',
#  9787,
#  9792,
#  'Alice',
#  10241,
#  10246,
#  'Alice',
#  10716,
#  10721,
#  'Alice',
#  11042,
#  11047,
#  'Alice',
#  11522,
#  11527,
# ...

# %%
for ent in doc.ents:
    if ent.label_ == "PERSON":
        print(ent.text,ent.start_char, ent.end_char)
        print(type([ent.text,ent.start_char, ent.end_char]))
# Out:
# Alice 526 531
# <class 'list'>
# Alice 918 923
# <class 'list'>
# Alice 1290 1295
# <class 'list'>
# Alice 1633 1638
# <class 'list'>
# Alice 1827 1832
# <class 'list'>
# Alice 2668 2673
# <class 'list'>
# Alice 3181 3186
# <class 'list'>
# Alice 3522 3527
# <class 'list'>
# Alice 4375 4380
# <class 'list'>
# Dinah'll 4409 4417
# <class 'list'>
# Dinah 4465 4470
# <class 'list'>
# Dinah 4544 4549
# <class 'list'>
# Alice 4748 4753
# <class 'list'>
# Dinah 5112 5117
# <class 'list'>
# Dinah 5159 5164
# <class 'list'>
# Alice 5318 5323
# <class 'list'>
# Alice 5578 5583
# <class 'list'>
# Rabbit 5770 5776
# <class 'list'>
# Alice 5976 5981
# <class 'list'>
# Alice 6267 6272
# <class 'list'>
# Alice 6700 6705
# <class 'list'>
# Alice 7117 7122
# <class 'list'>
# Alice 7347 7352
# <class 'list'>
# Alice 7721 7726
# <class 'list'>
# Alice 7914 7919
# <class 'list'>
# Alice 8602 8607
# <class 'list'>
# Alice 9011 9016
# <class 'list'>
# Alice 9419 9424
# <class 'list'>
# Alice 9787 9792
# ...

# %%
from spacy import displacy

# %%
import spacy
from spacy import displacy

# In[2]:
#doc = nlp("Rats are various medium-sized, long-tailed rodents.")
#displacy.render(doc, style="dep")

# In[3]:
#doc2 = nlp(LONG_NEWS_ARTICLE)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Alice's Adventures in Wonderland</br></br>                ALICE'S ADVENTURES IN WONDERLAND</br></br>                          Lewis Carroll</br></br>               THE MILLENNIUM FULCRUM EDITION 3.0</br></br></br></br></br>                            CHAPTER I</br></br>                      Down the Rabbit-Hole</br></br></br>  Alice was beginning to get very tired of sitting by her sister</br>on the bank, and of having nothing to do:  once or twice she had</br>peeped into the book her sister was reading, but it had no</br>pictures or conversations in it, `and what is the use of a book,'</br>thought
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# ...
